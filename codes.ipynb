# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
cities = pd.read_csv('Dataset/dim_cities.csv')
respondents = pd.read_csv('Dataset/dim_respondents.csv')
survey = pd.read_csv('Dataset/fact_survey_responses.csv')

# %%
cities
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2
# 5   CT116  Hyderabad  Tier 1
# 6   CT117  Ahmedabad  Tier 2
# 7   CT118       Pune  Tier 2
# 8   CT119     Jaipur  Tier 2
# 9   CT120    Lucknow  Tier 2

# %%
respondents
# Out:
#       Respondent_ID               Name    Age  Gender City_ID
# 0            120031     Aniruddh Issac  15-18  Female   CT117
# 1            120032        Trisha Rout  19-30    Male   CT118
# 2            120033       Yuvraj  Virk  15-18    Male   CT116
# 3            120034       Pranay Chand  31-45  Female   CT113
# 4            120035     Mohanlal Joshi  19-30  Female   CT120
# ...             ...                ...    ...     ...     ...
# 9995         130026         Arnav Kale  31-45    Male   CT112
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114
# 9998         130029        Jayan Goyal  19-30    Male   CT113
# 9999         130030         Piya Varty  15-18    Male   CT112
#
# [10000 rows x 5 columns]

# %%
survey
# Out:
#       Response_ID  Respondent_ID  Consume_frequency  \
# 0          103001         120031   2-3 times a week
# 1          103002         120032  2-3 times a month
# 2          103003         120033             Rarely
# 3          103004         120034   2-3 times a week
# 4          103005         120035              Daily
# ...           ...            ...                ...
# 9995       112996         130026              Daily
# 9996       112997         130027              Daily
# 9997       112998         130028              Daily
# 9998       112999         130029   2-3 times a week
# 9999       113000         130030              Daily
#
#                          Consume_time                 Consume_reason  \
# 0     To stay awake during work/study     Increased energy and focus
# 1                  Throughout the day           To boost performance
# 2                     Before exercise     Increased energy and focus
# 3     To stay awake during work/study           To boost performance
# 4     To stay awake during work/study     Increased energy and focus
# ...                               ...                            ...
# 9995                  Before exercise  To enhance sports performance
# 9996  To stay awake during work/study              To combat fatigue
# 9997                  Before exercise     Increased energy and focus
# 9998  To stay awake during work/study     Increased energy and focus
# 9999             For mental alertness                          Other
#
#      Heard_before Brand_perception General_perception Tried_before  \
# 0             Yes          Neutral           Not sure           No
# 1              No          Neutral           Not sure           No
# 2              No          Neutral           Not sure           No
# 3              No         Positive          Dangerous          Yes
# 4             Yes          Neutral          Effective          Yes
# ...           ...              ...                ...          ...
# 9995          Yes          Neutral           Not sure           No
# 9996           No         Positive            Healthy          Yes
# 9997          Yes         Positive          Effective           No
# 9998           No         Positive            Healthy           No
# 9999          Yes         Positive          Effective           No
#
#       Taste_experience  ...      Improvements_desired Ingredients_expected  \
# 0                    5  ...     Reduced sugar content              Guarana
# 1                    5  ...  More natural ingredients             Caffeine
# 2                    2  ...  More natural ingredients             Caffeine
# 3                    5  ...                     Other             Caffeine
# 4                    5  ...  More natural ingredients             Caffeine
# ...                ...  ...                       ...                  ...
# 9995                 4  ...                     Other             Caffeine
# 9996                 2  ...  More natural ingredients             Caffeine
# 9997                 2  ...                     Other             Caffeine
# 9998                 4  ...                     Other                Sugar
# 9999                 4  ...    Wider range of flavors             Caffeine
#
#      Health_concerns Interest_in_natural_or_organic  Marketing_channels  \
# 0                 No                            Yes      TV commercials
# 1                Yes                       Not Sure         Print media
# 2                 No                            Yes          Online ads
# 3                 No                            Yes          Online ads
# 4                Yes                            Yes          Online ads
# ...              ...                            ...                 ...
# 9995              No                             No         Print media
# 9996              No                             No      TV commercials
# 9997             Yes                             No  Outdoor billboards
# 9998             Yes                            Yes          Online ads
# 9999             Yes                       Not Sure         Print media
#
#            Packaging_preference Limited_edition_packaging Price_range  \
# 0     Compact and portable cans                       Yes       50-99
# 1     Compact and portable cans                        No       50-99
# 2      Innovative bottle design                  Not Sure     100-150
# 3     Compact and portable cans                        No   Above 150
# 4     Compact and portable cans                       Yes     100-150
# ...                         ...                       ...         ...
# 9995  Compact and portable cans                       Yes     100-150
# 9996                      Other                       Yes       50-99
# 9997  Compact and portable cans                        No     100-150
# 9998  Compact and portable cans                  Not Sure       50-99
# 9999        Eco-friendly design                        No       50-99
#
#      Purchase_location Typical_consumption_situations
# 0         Supermarkets          Studying/working late
# 1         Supermarkets                Sports/exercise
# 2         Supermarkets          Studying/working late
# 3         Supermarkets                Sports/exercise
# 4     Online retailers          Studying/working late
# ...                ...                            ...
# 9995      Supermarkets          Studying/working late
# 9996  Online retailers         Social outings/parties
# 9997             Other                Sports/exercise
# 9998      Supermarkets          Studying/working late
# 9999      Supermarkets                Sports/exercise
#
# [10000 rows x 23 columns]

# %% [markdown]
# ## Let's Join the dataframe to make one single dataframe

# %%
respondents.merge(cities,on='City_ID',how='left')
# Out:
#       Respondent_ID               Name    Age  Gender City_ID       City  \
# 0            120031     Aniruddh Issac  15-18  Female   CT117  Ahmedabad
# 1            120032        Trisha Rout  19-30    Male   CT118       Pune
# 2            120033       Yuvraj  Virk  15-18    Male   CT116  Hyderabad
# 3            120034       Pranay Chand  31-45  Female   CT113  Bangalore
# 4            120035     Mohanlal Joshi  19-30  Female   CT120    Lucknow
# ...             ...                ...    ...     ...     ...        ...
# 9995         130026         Arnav Kale  31-45    Male   CT112     Mumbai
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113  Bangalore
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114    Chennai
# 9998         130029        Jayan Goyal  19-30    Male   CT113  Bangalore
# 9999         130030         Piya Varty  15-18    Male   CT112     Mumbai
#
#         Tier
# 0     Tier 2
# 1     Tier 2
# 2     Tier 1
# 3     Tier 1
# 4     Tier 2
# ...      ...
# 9995  Tier 1
# 9996  Tier 1
# 9997  Tier 1
# 9998  Tier 1
# 9999  Tier 1
#
# [10000 rows x 7 columns]

# %%
respondents.merge(cities,on='City_ID',how='left').merge(survey,on='Respondent_ID',how='left')
# Out:
#       Respondent_ID               Name    Age  Gender City_ID       City  \
# 0            120031     Aniruddh Issac  15-18  Female   CT117  Ahmedabad
# 1            120032        Trisha Rout  19-30    Male   CT118       Pune
# 2            120033       Yuvraj  Virk  15-18    Male   CT116  Hyderabad
# 3            120034       Pranay Chand  31-45  Female   CT113  Bangalore
# 4            120035     Mohanlal Joshi  19-30  Female   CT120    Lucknow
# ...             ...                ...    ...     ...     ...        ...
# 9995         130026         Arnav Kale  31-45    Male   CT112     Mumbai
# 9996         130027    Yuvraj  Agrawal  15-18    Male   CT113  Bangalore
# 9997         130028  Vardaniya Chauhan  31-45    Male   CT114    Chennai
# 9998         130029        Jayan Goyal  19-30    Male   CT113  Bangalore
# 9999         130030         Piya Varty  15-18    Male   CT112     Mumbai
#
#         Tier  Response_ID  Consume_frequency                     Consume_time  \
# 0     Tier 2       103001   2-3 times a week  To stay awake during work/study
# 1     Tier 2       103002  2-3 times a month               Throughout the day
# 2     Tier 1       103003             Rarely                  Before exercise
# 3     Tier 1       103004   2-3 times a week  To stay awake during work/study
# 4     Tier 2       103005              Daily  To stay awake during work/study
# ...      ...          ...                ...                              ...
# 9995  Tier 1       112996              Daily                  Before exercise
# 9996  Tier 1       112997              Daily  To stay awake during work/study
# 9997  Tier 1       112998              Daily                  Before exercise
# 9998  Tier 1       112999   2-3 times a week  To stay awake during work/study
# 9999  Tier 1       113000              Daily             For mental alertness
#
#       ...      Improvements_desired Ingredients_expected Health_concerns  \
# 0     ...     Reduced sugar content              Guarana              No
# 1     ...  More natural ingredients             Caffeine             Yes
# 2     ...  More natural ingredients             Caffeine              No
# 3     ...                     Other             Caffeine              No
# 4     ...  More natural ingredients             Caffeine             Yes
# ...   ...                       ...                  ...             ...
# 9995  ...                     Other             Caffeine              No
# 9996  ...  More natural ingredients             Caffeine              No
# 9997  ...                     Other             Caffeine             Yes
# 9998  ...                     Other                Sugar             Yes
# 9999  ...    Wider range of flavors             Caffeine             Yes
#
#      Interest_in_natural_or_organic  Marketing_channels  \
# 0                               Yes      TV commercials
# 1                          Not Sure         Print media
# 2                               Yes          Online ads
# 3                               Yes          Online ads
# 4                               Yes          Online ads
# ...                             ...                 ...
# 9995                             No         Print media
# 9996                             No      TV commercials
# 9997                             No  Outdoor billboards
# 9998                            Yes          Online ads
# 9999                       Not Sure         Print media
#
#            Packaging_preference Limited_edition_packaging Price_range  \
# 0     Compact and portable cans                       Yes       50-99
# 1     Compact and portable cans                        No       50-99
# 2      Innovative bottle design                  Not Sure     100-150
# 3     Compact and portable cans                        No   Above 150
# 4     Compact and portable cans                       Yes     100-150
# ...                         ...                       ...         ...
# 9995  Compact and portable cans                       Yes     100-150
# 9996                      Other                       Yes       50-99
# 9997  Compact and portable cans                        No     100-150
# 9998  Compact and portable cans                  Not Sure       50-99
# 9999        Eco-friendly design                        No       50-99
#
#      Purchase_location Typical_consumption_situations
# 0         Supermarkets          Studying/working late
# 1         Supermarkets                Sports/exercise
# 2         Supermarkets          Studying/working late
# 3         Supermarkets                Sports/exercise
# 4     Online retailers          Studying/working late
# ...                ...                            ...
# 9995      Supermarkets          Studying/working late
# 9996  Online retailers         Social outings/parties
# 9997             Other                Sports/exercise
# 9998      Supermarkets          Studying/working late
# 9999      Supermarkets                Sports/exercise
#
# [10000 rows x 29 columns]

# %%
respondents.merge(cities,on='City_ID',how='left').merge(survey,on='Respondent_ID',how='left').columns
# Out:
# Index(['Respondent_ID', 'Name', 'Age', 'Gender', 'City_ID', 'City', 'Tier',
#        'Response_ID', 'Consume_frequency', 'Consume_time', 'Consume_reason',
#        'Heard_before', 'Brand_perception', 'General_perception',
#        'Tried_before', 'Taste_experience', 'Reasons_preventing_trying',
#        'Current_brands', 'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')

# %% [markdown]
# ## Make a new dataframe

# %%
df = respondents.merge(cities,on='City_ID',how='left').merge(survey,on='Respondent_ID',how='left')

# %% [markdown]
# ## Let's find some Demographic Insights like
# ## Who prefers energy drink more? (male/female/non-binary?)
# ### To find it out we're gonna focus on two colums 'Gender' and 'Consume_frequency'

# %%
df['Consume_frequency'].value_counts()
# Out:
# Consume_frequency
# 2-3 times a week     3491
# Rarely               1941
# 2-3 times a month    1613
# Once a week          1609
# Daily                1346
# Name: count, dtype: int64

# %% [markdown]
# ## We can get rid of the people who drinks rarely

# %%
df_drinks_more = df.query("Consume_frequency!='Rarely'").copy()

# %%
df_drinks_more.head()
# Out:
#    Respondent_ID            Name    Age  Gender City_ID       City    Tier  \
# 0         120031  Aniruddh Issac  15-18  Female   CT117  Ahmedabad  Tier 2
# 1         120032     Trisha Rout  19-30    Male   CT118       Pune  Tier 2
# 3         120034    Pranay Chand  31-45  Female   CT113  Bangalore  Tier 1
# 4         120035  Mohanlal Joshi  19-30  Female   CT120    Lucknow  Tier 2
# 6         120037      Oorja Anne  19-30    Male   CT112     Mumbai  Tier 1
#
#    Response_ID  Consume_frequency                     Consume_time  ...  \
# 0       103001   2-3 times a week  To stay awake during work/study  ...
# 1       103002  2-3 times a month               Throughout the day  ...
# 3       103004   2-3 times a week  To stay awake during work/study  ...
# 4       103005              Daily  To stay awake during work/study  ...
# 6       103007  2-3 times a month  To stay awake during work/study  ...
#
#        Improvements_desired Ingredients_expected Health_concerns  \
# 0     Reduced sugar content              Guarana              No
# 1  More natural ingredients             Caffeine             Yes
# 3                     Other             Caffeine              No
# 4  More natural ingredients             Caffeine             Yes
# 6                     Other              Guarana             Yes
#
#   Interest_in_natural_or_organic Marketing_channels  \
# 0                            Yes     TV commercials
# 1                       Not Sure        Print media
# 3                            Yes         Online ads
# 4                            Yes         Online ads
# 6                             No         Online ads
#
#         Packaging_preference Limited_edition_packaging Price_range  \
# 0  Compact and portable cans                       Yes       50-99
# 1  Compact and portable cans                        No       50-99
# 3  Compact and portable cans                        No   Above 150
# 4  Compact and portable cans                       Yes     100-150
# 6   Innovative bottle design                       Yes     100-150
#
#   Purchase_location Typical_consumption_situations
# 0      Supermarkets          Studying/working late
# 1      Supermarkets                Sports/exercise
# 3      Supermarkets                Sports/exercise
# 4  Online retailers          Studying/working late
# 6             Other                Sports/exercise
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Using groupby to get in general count

# %%
df_drinks_more.groupby(['Gender'])['Consume_frequency'].count()
# Out:
# Gender
# Female        2793
# Male          4852
# Non-binary     414
# Name: Consume_frequency, dtype: int64

# %% [markdown]
# ## According to this process males consume more energy drinks

# %%
df_drinks_more.groupby(['Gender'])['Consume_frequency'].count().sort_values(ascending=False)
# Out:
# Gender
# Male          4852
# Female        2793
# Non-binary     414
# Name: Consume_frequency, dtype: int64

# %% [markdown]
# ## To be more presize we can assign a weight accoring to the consumption frequency

# %%
weights = {
    'Daily': 30,
    '2-3 times a week': 12,
    'Once a week': 4,
    '2-3 times a month': 3,
}

# %% [markdown]
# ## Now we can create a new column and map these weights to the 'Consume_frequency' column

# %%
df_drinks_more['Consume_weight'] = df['Consume_frequency'].map(weights)

# %% [markdown]
# ## Let's check it out

# %%
df_drinks_more.head()
# Out:
#    Respondent_ID            Name    Age  Gender City_ID       City    Tier  \
# 0         120031  Aniruddh Issac  15-18  Female   CT117  Ahmedabad  Tier 2
# 1         120032     Trisha Rout  19-30    Male   CT118       Pune  Tier 2
# 3         120034    Pranay Chand  31-45  Female   CT113  Bangalore  Tier 1
# 4         120035  Mohanlal Joshi  19-30  Female   CT120    Lucknow  Tier 2
# 6         120037      Oorja Anne  19-30    Male   CT112     Mumbai  Tier 1
#
#    Response_ID  Consume_frequency                     Consume_time  ...  \
# 0       103001   2-3 times a week  To stay awake during work/study  ...
# 1       103002  2-3 times a month               Throughout the day  ...
# 3       103004   2-3 times a week  To stay awake during work/study  ...
# 4       103005              Daily  To stay awake during work/study  ...
# 6       103007  2-3 times a month  To stay awake during work/study  ...
#
#   Ingredients_expected Health_concerns Interest_in_natural_or_organic  \
# 0              Guarana              No                            Yes
# 1             Caffeine             Yes                       Not Sure
# 3             Caffeine              No                            Yes
# 4             Caffeine             Yes                            Yes
# 6              Guarana             Yes                             No
#
#   Marketing_channels       Packaging_preference  Limited_edition_packaging  \
# 0     TV commercials  Compact and portable cans                        Yes
# 1        Print media  Compact and portable cans                         No
# 3         Online ads  Compact and portable cans                         No
# 4         Online ads  Compact and portable cans                        Yes
# 6         Online ads   Innovative bottle design                        Yes
#
#   Price_range Purchase_location Typical_consumption_situations Consume_weight
# 0       50-99      Supermarkets          Studying/working late           12.0
# 1       50-99      Supermarkets                Sports/exercise            3.0
# 3   Above 150      Supermarkets                Sports/exercise           12.0
# 4     100-150  Online retailers          Studying/working late           30.0
# 6     100-150             Other                Sports/exercise            3.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Now if we apply the same groupby to get the counts

# %%
df_drinks_more.groupby('Gender')['Consume_weight'].sum().sort_values(ascending=False)
# Out:
# Gender
# Male          56434.0
# Female        32475.0
# Non-binary     4638.0
# Name: Consume_weight, dtype: float64

# %% [markdown]
# ## So we'll store the first element

# %%
gender_preffers_more_energy_drinks = df_drinks_more.groupby('Gender')['Consume_weight'].sum().sort_values(ascending=False).index[0]

# %%
print("The gender that prefers energy drinks the most is:",gender_preffers_more_energy_drinks)
# Out:
# The gender that prefers energy drinks the most is: Male

# %% [markdown]
# ## Let's find out what age group prefers energy drinks more, we can use the same dataframe

# %%
df_drinks_more.head()
# Out:
#    Respondent_ID            Name    Age  Gender City_ID       City    Tier  \
# 0         120031  Aniruddh Issac  15-18  Female   CT117  Ahmedabad  Tier 2
# 1         120032     Trisha Rout  19-30    Male   CT118       Pune  Tier 2
# 3         120034    Pranay Chand  31-45  Female   CT113  Bangalore  Tier 1
# 4         120035  Mohanlal Joshi  19-30  Female   CT120    Lucknow  Tier 2
# 6         120037      Oorja Anne  19-30    Male   CT112     Mumbai  Tier 1
#
#    Response_ID  Consume_frequency                     Consume_time  ...  \
# 0       103001   2-3 times a week  To stay awake during work/study  ...
# 1       103002  2-3 times a month               Throughout the day  ...
# 3       103004   2-3 times a week  To stay awake during work/study  ...
# 4       103005              Daily  To stay awake during work/study  ...
# 6       103007  2-3 times a month  To stay awake during work/study  ...
#
#   Ingredients_expected Health_concerns Interest_in_natural_or_organic  \
# 0              Guarana              No                            Yes
# 1             Caffeine             Yes                       Not Sure
# 3             Caffeine              No                            Yes
# 4             Caffeine             Yes                            Yes
# 6              Guarana             Yes                             No
#
#   Marketing_channels       Packaging_preference  Limited_edition_packaging  \
# 0     TV commercials  Compact and portable cans                        Yes
# 1        Print media  Compact and portable cans                         No
# 3         Online ads  Compact and portable cans                         No
# 4         Online ads  Compact and portable cans                        Yes
# 6         Online ads   Innovative bottle design                        Yes
#
#   Price_range Purchase_location Typical_consumption_situations Consume_weight
# 0       50-99      Supermarkets          Studying/working late           12.0
# 1       50-99      Supermarkets                Sports/exercise            3.0
# 3   Above 150      Supermarkets                Sports/exercise           12.0
# 4     100-150  Online retailers          Studying/working late           30.0
# 6     100-150             Other                Sports/exercise            3.0
#
# [5 rows x 30 columns]

# %%
df_drinks_more.groupby(['Age'])['Consume_weight'].sum().sort_values(ascending=False)
# Out:
# Age
# 19-30    51309.0
# 31-45    22786.0
# 15-18    14020.0
# 46-65     3662.0
# 65+       1770.0
# Name: Consume_weight, dtype: float64

# %% [markdown]
# ## Finally to the age group that consumes more enery drinks

# %%
age_group_consume_more = df_drinks_more.groupby(['Age'])['Consume_weight'].sum().sort_values(ascending=False).index[0]

# %%
print("The age group that consume more energy drinks is:",age_group_consume_more)
# Out:
# The age group that consume more energy drinks is: 19-30

# %% [markdown]
# ## Let's find out what type of marketing reaches the most Youth (15-30)

# %%
df['Age'].value_counts()
# Out:
# Age
# 19-30    5520
# 31-45    2376
# 15-18    1488
# 46-65     426
# 65+       190
# Name: count, dtype: int64

# %% [markdown]
# ## First let's create a dataframe for the youth or that perticular age group

# %%
df_youth_marketing_channels = df.query("(Age == '15-18')|(Age == '19-30')").copy()

# %%
df_youth_marketing_channels.head()
# Out:
#    Respondent_ID            Name    Age  Gender City_ID       City    Tier  \
# 0         120031  Aniruddh Issac  15-18  Female   CT117  Ahmedabad  Tier 2
# 1         120032     Trisha Rout  19-30    Male   CT118       Pune  Tier 2
# 2         120033    Yuvraj  Virk  15-18    Male   CT116  Hyderabad  Tier 1
# 4         120035  Mohanlal Joshi  19-30  Female   CT120    Lucknow  Tier 2
# 5         120036   Zeeshan Ratta  19-30  Female   CT118       Pune  Tier 2
#
#    Response_ID  Consume_frequency                     Consume_time  ...  \
# 0       103001   2-3 times a week  To stay awake during work/study  ...
# 1       103002  2-3 times a month               Throughout the day  ...
# 2       103003             Rarely                  Before exercise  ...
# 4       103005              Daily  To stay awake during work/study  ...
# 5       103006             Rarely             For mental alertness  ...
#
#        Improvements_desired Ingredients_expected Health_concerns  \
# 0     Reduced sugar content              Guarana              No
# 1  More natural ingredients             Caffeine             Yes
# 2  More natural ingredients             Caffeine              No
# 4  More natural ingredients             Caffeine             Yes
# 5    Wider range of flavors             Vitamins             Yes
#
#   Interest_in_natural_or_organic Marketing_channels  \
# 0                            Yes     TV commercials
# 1                       Not Sure        Print media
# 2                            Yes         Online ads
# 4                            Yes         Online ads
# 5                            Yes     TV commercials
#
#         Packaging_preference Limited_edition_packaging Price_range  \
# 0  Compact and portable cans                       Yes       50-99
# 1  Compact and portable cans                        No       50-99
# 2   Innovative bottle design                  Not Sure     100-150
# 4  Compact and portable cans                       Yes     100-150
# 5                      Other                       Yes   Above 150
#
#           Purchase_location Typical_consumption_situations
# 0              Supermarkets          Studying/working late
# 1              Supermarkets                Sports/exercise
# 2              Supermarkets          Studying/working late
# 4          Online retailers          Studying/working late
# 5  Gyms and fitness centers         Social outings/parties
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Now we can just count unique values of marketing channels

# %%
df_youth_marketing_channels['Marketing_channels'].value_counts()
# Out:
# Marketing_channels
# Online ads            3373
# TV commercials        1785
# Other                  702
# Outdoor billboards     702
# Print media            446
# Name: count, dtype: int64

# %% [markdown]
# ## Since it's a sorted series we can just get the first series

# %%
youth_marketing_channels = df_youth_marketing_channels['Marketing_channels'].value_counts().index[0]

# %%
youth_marketing_channels
# Out:
# 'Online ads'

# %%
print("The type of marketing reaches the most Youth (15-30) is: ", youth_marketing_channels)
# Out:
# The type of marketing reaches the most Youth (15-30) is:  Online ads

# %% [markdown]
# # Consumer Preferences:
# ## Let's find out about the preferred ingredients of energy drinks among respondents

# %%
df.head()
# Out:
#    Respondent_ID            Name    Age  Gender City_ID       City    Tier  \
# 0         120031  Aniruddh Issac  15-18  Female   CT117  Ahmedabad  Tier 2
# 1         120032     Trisha Rout  19-30    Male   CT118       Pune  Tier 2
# 2         120033    Yuvraj  Virk  15-18    Male   CT116  Hyderabad  Tier 1
# 3         120034    Pranay Chand  31-45  Female   CT113  Bangalore  Tier 1
# 4         120035  Mohanlal Joshi  19-30  Female   CT120    Lucknow  Tier 2
#
#    Response_ID  Consume_frequency                     Consume_time  ...  \
# 0       103001   2-3 times a week  To stay awake during work/study  ...
# 1       103002  2-3 times a month               Throughout the day  ...
# 2       103003             Rarely                  Before exercise  ...
# 3       103004   2-3 times a week  To stay awake during work/study  ...
# 4       103005              Daily  To stay awake during work/study  ...
#
#        Improvements_desired Ingredients_expected Health_concerns  \
# 0     Reduced sugar content              Guarana              No
# 1  More natural ingredients             Caffeine             Yes
# 2  More natural ingredients             Caffeine              No
# 3                     Other             Caffeine              No
# 4  More natural ingredients             Caffeine             Yes
#
#   Interest_in_natural_or_organic Marketing_channels  \
# 0                            Yes     TV commercials
# 1                       Not Sure        Print media
# 2                            Yes         Online ads
# 3                            Yes         Online ads
# 4                            Yes         Online ads
#
#         Packaging_preference Limited_edition_packaging Price_range  \
# 0  Compact and portable cans                       Yes       50-99
# 1  Compact and portable cans                        No       50-99
# 2   Innovative bottle design                  Not Sure     100-150
# 3  Compact and portable cans                        No   Above 150
# 4  Compact and portable cans                       Yes     100-150
#
#   Purchase_location Typical_consumption_situations
# 0      Supermarkets          Studying/working late
# 1      Supermarkets                Sports/exercise
# 2      Supermarkets          Studying/working late
# 3      Supermarkets                Sports/exercise
# 4  Online retailers          Studying/working late
#
# [5 rows x 29 columns]

# %%
df['Ingredients_expected'].value_counts()
# Out:
# Ingredients_expected
# Caffeine    3896
# Vitamins    2534
# Sugar       2017
# Guarana     1553
# Name: count, dtype: int64

# %% [markdown]
# ## If we plot a pie chart

# %%
df['Ingredients_expected'].value_counts().plot(kind='pie',autopct='%1.2f%%',ylabel='')
plt.show()

# %% [markdown]
# ## Let's find out what packaging preferences do respondents have for energy drinks?

# %%
df.columns
# Out:
# Index(['Respondent_ID', 'Name', 'Age', 'Gender', 'City_ID', 'City', 'Tier',
#        'Response_ID', 'Consume_frequency', 'Consume_time', 'Consume_reason',
#        'Heard_before', 'Brand_perception', 'General_perception',
#        'Tried_before', 'Taste_experience', 'Reasons_preventing_trying',
#        'Current_brands', 'Reasons_for_choosing_brands', 'Improvements_desired',
#        'Ingredients_expected', 'Health_concerns',
#        'Interest_in_natural_or_organic', 'Marketing_channels',
#        'Packaging_preference', 'Limited_edition_packaging', 'Price_range',
#        'Purchase_location', 'Typical_consumption_situations'],
#       dtype='object')
